# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import log_loss

# %%
df = pd.read_csv('gbm-data.csv')
df[:2]
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
#
#          D8        D9  ...    D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...        0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...        1      1      1      1      0      1      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
#
# [2 rows x 1777 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['Activity'], axis=1).values, df['Activity'].values,
                                                    test_size=0.8, random_state=241)

# %%
learning_rate = [1, 0.5, 0.3, 0.2, 0.1]
for i in learning_rate:
    gb = GradientBoostingClassifier(n_estimators=250, verbose=True, random_state=241, learning_rate=i)
    gb.fit(X_train, y_train)
    print (gb.staged_decision_function(X_train))
#     gb.staged_decision_function(X_test)
    
#     gb.predict_proba(X_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.0190           12.45s
#          2           0.9192           12.52s
#          3           0.8272           12.10s
#          4           0.7834           11.74s
#          5           0.7109           11.81s
#          6           0.6368           11.83s
#          7           0.5797           11.66s
#          8           0.5610           11.40s
#          9           0.5185           11.27s
#         10           0.4984           11.18s
#         20           0.1999           10.55s
#         30           0.1313            9.96s
#         40           0.0790            9.47s
#         50           0.0511            8.99s
#         60           0.0352            8.50s
#         70           0.0245            8.03s
#         80           0.0162            7.57s
#         90           0.0114            7.11s
#        100           0.0077            6.66s
#        200           0.0004            1.98s
# ...
